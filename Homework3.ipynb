# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !java -version

# !update-alternatives --set java /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java
# !update-alternatives --set javac /usr/lib/jvm/java-8-openjdk-amd64/bin/javac
# !update-alternatives --set jps /usr/lib/jvm/java-8-openjdk-amd64/bin/jps
# !java -version

#Finding the default Java path
# !readlink -f /usr/bin/java | sed "s:bin/java::"
# !apt-get install openssh-server -qq > /dev/null
# !service ssh start

# !grep Port /etc/ssh/sshd_config

#Creating a new rsa key pair with empty password
# !ssh-keygen -t rsa -P "" -f ~/.ssh/id_rsa <<< y

# See id_rsa.pub content
# !more /root/.ssh/id_rsa.pub

#Copying the key to autorized keys
# !cat $HOME/.ssh/id_rsa.pub > $HOME/.ssh/authorized_keys
#Changing the permissions on the key
# !chmod 0600 ~/.ssh/authorized_keys

#Conneting with the local machine
# !ssh -o StrictHostKeyChecking=no localhost uptime

#Downloading Hadoop 3.2.3
# !wget -q https://archive.apache.org/dist/hadoop/common/hadoop-3.2.3/hadoop-3.2.3.tar.gz

#Untarring the file
# !sudo tar -xzf hadoop-3.2.3.tar.gz
#Removing the tar file
# !rm hadoop-3.2.3.tar.gz

#Copying the hadoop files to user/local
# !cp -r hadoop-3.2.3/ /usr/local/
#-r copy directories recursively

#Adding JAVA_HOME directory to hadoop-env.sh file
# !sed -i '/export JAVA_HOME=/a export JAVA_HOME=\/usr\/lib\/jvm\/java-8-openjdk-amd64' /usr/local/hadoop-3.2.3/etc/hadoop/hadoop-env.sh

import os
#Creating environment variables
#Creating Hadoop home variable

os.environ["HADOOP_HOME"] = "/usr/local/hadoop-3.2.3"
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["JRE_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64/jre"
os.environ["PATH"] += f'{os.environ["JAVA_HOME"]}/bin:{os.environ["JRE_HOME"]}/bin:{os.environ["HADOOP_HOME"]}/sbin'

# !$HADOOP_HOME/bin/hdfs namenode -format

#Creating other necessary enviroment variables before starting nodes
os.environ["HDFS_NAMENODE_USER"] = "root"
os.environ["HDFS_DATANODE_USER"] = "root"
os.environ["HDFS_SECONDARYNAMENODE_USER"] = "root"
os.environ["YARN_RESOURCEMANAGER_USER"] = "root"
os.environ["YARN_NODEMANAGER_USER"] = "root"

#Launching hdfs deamons
# !$HADOOP_HOME/sbin/start-dfs.sh

#Launching yarn deamons
#nohup causes a process to ignore a SIGHUP signal
# !nohup $HADOOP_HOME/sbin/start-yarn.sh

#Listing the running deamons
# !jps

# !$HADOOP_HOME/bin/hdfs dfs -mkdir /word_count_python

# !$HADOOP_HOME/bin/hdfs dfs -put /content/pembukaan_uud1945.txt /word_count_python
# Out:
# openjdk version "11.0.24" 2024-07-16
# OpenJDK Runtime Environment (build 11.0.24+8-post-Ubuntu-1ubuntu322.04)
# OpenJDK 64-Bit Server VM (build 11.0.24+8-post-Ubuntu-1ubuntu322.04, mixed mode, sharing)
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java to provide /usr/bin/java (java) in manual mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/javac to provide /usr/bin/javac (javac) in manual mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jps to provide /usr/bin/jps (jps) in manual mode
# openjdk version "1.8.0_422"
# OpenJDK Runtime Environment (build 1.8.0_422-8u422-b05-1~22.04-b05)
# OpenJDK 64-Bit Server VM (build 25.422-b05, mixed mode)
# /usr/lib/jvm/java-8-openjdk-amd64/jre/
#  * Starting OpenBSD Secure Shell server sshd
#    ...done.
# #Port 22
# #GatewayPorts no
# Generating public/private rsa key pair.
# Created directory '/root/.ssh'.
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:P7GJtXFRlQzpN2q2RvTyn02Y3fCpcak5a+XvcsrgaQo root@5982aab5062b
# The key's randomart image is:
# +---[RSA 3072]----+
# |             .=.o|
# |             o o |
# |            o    |
# |             + o |
# |        S + o = .|
# |         + B * O+|
# |        E * =.O+=|
# |         . o.OB++|
# |          .o===*B|
# +----[SHA256]-----+
# ssh-rsa AAAAB3NzaC1yc2EAAAADAQABAAABgQCo+2XhIWt5ZlInAAb+Ftd5rBVPF/Ro89nM9gCxb1QLZXlC/XSbI0b4wK3RLqgX
# XGqSy+6E32I0Mw2sr/wivU4A2rLMtbgbjdBYqOo6AjNeGzTIH84IQtPyWdpeLOxvJcPeKyViKPHre11Qgd9wy3Ed8V8L+2U3c/OL
# 05GyyVzWMnXHOwpmy+48sytZFrSEZKMV9H52G9N0SeDSxJCGr7VYDVZtINyiuz+OIRZsO8kJAQrzuS0TGekN8la5t+1FnNLHTCcT
# gPyVnjlja3gUP27IfUh4iufs9LMJ+ZDBXO3Rc/VPHb4Bk4tSb5RAB1GFfs0tlHOeZ+UNnqHMA9IxcPfInDa1yYgIj0M/VnN5Lv8V
# YBhBlWYO6ce28LVH1p9SKeaziXIXBVHdAfypZ4tI92Naj+X3xkwLibVhTGJ2ueU6fzbZ018+Ea1fELwrj/nUMR77VMHGq1DcDHup
# 0AhhlCYI3Yf9o3BlTJOaeFTnHOiWszn7MWgTY2MaAr+P6NGcXgs= root@5982aab5062b
# Warning: Permanently added 'localhost' (ED25519) to the list of known hosts.
#  14:29:26 up 2 min,  0 users,  load average: 1.83, 0.98, 0.39
# WARNING: /usr/local/hadoop-3.2.3/logs does not exist. Creating.
# 2024-08-17 14:30:11,458 INFO namenode.NameNode: STARTUP_MSG:
# /************************************************************
# STARTUP_MSG: Starting NameNode
# STARTUP_MSG:   host = 5982aab5062b/172.28.0.12
# STARTUP_MSG:   args = [-format]
# STARTUP_MSG:   version = 3.2.3
# STARTUP_MSG:   classpath = /usr/local/hadoop-3.2.3/etc/hadoop:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/dnsjava-2.1.7.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/checker-qual-2.5.2.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/guava-27.0-jre.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/spotbugs-annotations-3.1.9.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/jetty-util-ajax-9.4.40.v20210413.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/avro-1.7.7.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/log4j-1.2.17.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/commons-logging-1.1.3.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/kerby-asn1-1.0.1.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/jsp-api-2.1.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/zookeeper-3.4.14.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/commons-beanutils-1.9.4.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/commons-configuration2-2.1.1.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/slf4j-api-1.7.25.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/snappy-java-1.0.5.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/kerb-server-1.0.1.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/hadoop-annotations-3.2.3.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/jsr305-3.0.2.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/curator-recipes-2.13.0.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/httpcore-4.4.13.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/curator-framework-2.13.0.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/jackson-core-2.10.5.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/commons-cli-1.2.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/jcip-annotations-1.0-1.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/jetty-server-9.4.40.v20210413.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/commons-net-3.6.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/token-provider-1.0.1.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/nimbus-jose-jwt-9.8.1.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/netty-3.10.6.Final.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/commons-lang3-3.7.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/kerb-admin-1.0.1.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/kerb-simplekdc-1.0.1.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/kerb-util-1.0.1.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/kerb-common-1.0.1.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/commons-collections-3.2.2.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/httpclient-4.5.13.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/jackson-databind-2.10.5.1.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/asm-5.0.4.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/jsch-0.1.55.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/jackson-annotations-2.10.5.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/woodstox-core-5.3.0.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/failureaccess-1.0.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/curator-client-2.13.0.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/kerb-client-1.0.1.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/jackson-core-asl-1.9.13.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/jersey-json-1.19.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/jsr311-api-1.1.1.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/javax.activation-api-1.2.0.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/jetty-io-9.4.40.v20210413.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/audience-annotations-0.5.0.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/hadoop-auth-3.2.3.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/metrics-core-3.2.4.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/jersey-server-1.19.jar:/usr/local/hadoop-3.2.3/share/hadoop/common/lib/javax ...
# STARTUP_MSG:   build = https://github.com/apache/hadoop -r abe5358143720085498613d399be3bbf01e0f131; compiled by 'ubuntu' on 2022-03-20T01:18Z
# STARTUP_MSG:   java = 1.8.0_422
# ************************************************************/
# 2024-08-17 14:30:11,490 INFO namenode.NameNode: registered UNIX signal handlers for [TERM, HUP, INT]
# 2024-08-17 14:30:11,659 INFO namenode.NameNode: createNameNode [-format]
# Formatting using clusterid: CID-6d8e0586-62cb-4904-9f70-453b4684b0fb
# 2024-08-17 14:30:12,431 INFO namenode.FSEditLog: Edit logging is async:true
# 2024-08-17 14:30:12,470 INFO namenode.FSNamesystem: KeyProvider: null
# 2024-08-17 14:30:12,474 INFO namenode.FSNamesystem: fsLock is fair: true
# 2024-08-17 14:30:12,475 INFO namenode.FSNamesystem: Detailed lock hold time metrics enabled: false
# 2024-08-17 14:30:12,484 INFO namenode.FSNamesystem: fsOwner             = root (auth:SIMPLE)
# 2024-08-17 14:30:12,484 INFO namenode.FSNamesystem: supergroup          = supergroup
# 2024-08-17 14:30:12,485 INFO namenode.FSNamesystem: isPermissionEnabled = true
# 2024-08-17 14:30:12,485 INFO namenode.FSNamesystem: HA Enabled: false
# 2024-08-17 14:30:12,547 INFO common.Util: dfs.datanode.fileio.profiling.sampling.percentage set to 0. Disabling file IO profiling
# 2024-08-17 14:30:12,558 INFO blockmanagement.DatanodeManager: dfs.block.invalidate.limit: configured=1000, counted=60, effected=1000
# 2024-08-17 14:30:12,559 INFO blockmanagement.DatanodeManager: dfs.namenode.datanode.registration.ip-hostname-check=true
# 2024-08-17 14:30:12,564 INFO blockmanagement.BlockManager: dfs.namenode.startup.delay.block.deletion.sec is set to 000:00:00:00.000
# 2024-08-17 14:30:12,565 INFO blockmanagement.BlockManager: The block deletion will start around 2024 Aug 17 14:30:12
# 2024-08-17 14:30:12,567 INFO util.GSet: Computing capacity for map BlocksMap
# 2024-08-17 14:30:12,567 INFO util.GSet: VM type       = 64-bit
# 2024-08-17 14:30:12,569 INFO util.GSet: 2.0% max memory 2.8 GB = 57.7 MB
# 2024-08-17 14:30:12,569 INFO util.GSet: capacity      = 2^23 = 8388608 entries
# 2024-08-17 14:30:12,601 INFO blockmanagement.BlockManager: Storage policy satisfier is disabled
# 2024-08-17 14:30:12,602 INFO blockmanagement.BlockManager: dfs.block.access.token.enable = false
# 2024-08-17 14:30:12,609 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.threshold-pct = 0.9990000128746033
# 2024-08-17 14:30:12,609 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.min.datanodes = 0
# 2024-08-17 14:30:12,609 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.extension = 30000
# 2024-08-17 14:30:12,610 INFO blockmanagement.BlockManager: defaultReplication         = 3
# 2024-08-17 14:30:12,610 INFO blockmanagement.BlockManager: maxReplication             = 512
# 2024-08-17 14:30:12,610 INFO blockmanagement.BlockManager: minReplication             = 1
# 2024-08-17 14:30:12,610 INFO blockmanagement.BlockManager: maxReplicationStreams      = 2
# 2024-08-17 14:30:12,610 INFO blockmanagement.BlockManager: redundancyRecheckInterval  = 3000ms
# 2024-08-17 14:30:12,610 INFO blockmanagement.BlockManager: encryptDataTransfer        = false
# 2024-08-17 14:30:12,610 INFO blockmanagement.BlockManager: maxNumBlocksToLog          = 1000
# 2024-08-17 14:30:12,653 INFO namenode.FSDirectory: GLOBAL serial map: bits=29 maxEntries=536870911
# 2024-08-17 14:30:12,654 INFO namenode.FSDirectory: USER serial map: bits=24 maxEntries=16777215
# 2024-08-17 14:30:12,654 INFO namenode.FSDirectory: GROUP serial map: bits=24 maxEntries=16777215
# 2024-08-17 14:30:12,654 INFO namenode.FSDirectory: XATTR serial map: bits=24 maxEntries=16777215
# 2024-08-17 14:30:12,669 INFO util.GSet: Computing capacity for map INodeMap
# 2024-08-17 14:30:12,669 INFO util.GSet: VM type       = 64-bit
# 2024-08-17 14:30:12,669 INFO util.GSet: 1.0% max memory 2.8 GB = 28.9 MB
# 2024-08-17 14:30:12,669 INFO util.GSet: capacity      = 2^22 = 4194304 entries
# 2024-08-17 14:30:12,672 INFO namenode.FSDirectory: ACLs enabled? false
# 2024-08-17 14:30:12,672 INFO namenode.FSDirectory: POSIX ACL inheritance enabled? true
# 2024-08-17 14:30:12,672 INFO namenode.FSDirectory: XAttrs enabled? true
# 2024-08-17 14:30:12,673 INFO namenode.NameNode: Caching file names occurring more than 10 times
# 2024-08-17 14:30:12,678 INFO snapshot.SnapshotManager: Loaded config captureOpenFiles: false, skipCaptureAccessTimeOnlyChange: false, snapshotDiffAllowSnapRootDescendant: true, maxSnapshotLimit: 65536
# 2024-08-17 14:30:12,681 INFO snapshot.SnapshotManager: SkipList is disabled
# 2024-08-17 14:30:12,687 INFO util.GSet: Computing capacity for map cachedBlocks
# 2024-08-17 14:30:12,687 INFO util.GSet: VM type       = 64-bit
# 2024-08-17 14:30:12,687 INFO util.GSet: 0.25% max memory 2.8 GB = 7.2 MB
# 2024-08-17 14:30:12,687 INFO util.GSet: capacity      = 2^20 = 1048576 entries
# 2024-08-17 14:30:12,698 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.window.num.buckets = 10
# 2024-08-17 14:30:12,698 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.num.users = 10
# 2024-08-17 14:30:12,698 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.windows.minutes = 1,5,25
# 2024-08-17 14:30:12,703 INFO namenode.FSNamesystem: Retry cache on namenode is enabled
# 2024-08-17 14:30:12,703 INFO namenode.FSNamesystem: Retry cache will use 0.03 of total heap and retry cache entry expiry time is 600000 millis
# 2024-08-17 14:30:12,705 INFO util.GSet: Computing capacity for map NameNodeRetryCache
# 2024-08-17 14:30:12,706 INFO util.GSet: VM type       = 64-bit
# 2024-08-17 14:30:12,706 INFO util.GSet: 0.029999999329447746% max memory 2.8 GB = 886.4 KB
# 2024-08-17 14:30:12,706 INFO util.GSet: capacity      = 2^17 = 131072 entries
# 2024-08-17 14:30:12,740 INFO namenode.FSImage: Allocated new BlockPoolId: BP-1619697594-172.28.0.12-1723905012729
# 2024-08-17 14:30:12,802 INFO common.Storage: Storage directory /tmp/hadoop-root/dfs/name has been successfully formatted.
# 2024-08-17 14:30:12,848 INFO namenode.FSImageFormatProtobuf: Saving image file /tmp/hadoop-root/dfs/name/current/fsimage.ckpt_0000000000000000000 using no compression
# 2024-08-17 14:30:12,963 INFO namenode.FSImageFormatProtobuf: Image file /tmp/hadoop-root/dfs/name/current/fsimage.ckpt_0000000000000000000 of size 399 bytes saved in 0 seconds .
# 2024-08-17 14:30:12,983 INFO namenode.NNStorageRetentionManager: Going to retain 1 images with txid >= 0
# 2024-08-17 14:30:13,028 INFO namenode.FSNamesystem: Stopping services started for active state
# 2024-08-17 14:30:13,029 INFO namenode.FSNamesystem: Stopping services started for standby state
# 2024-08-17 14:30:13,038 INFO namenode.FSImage: FSImageSaver clean checkpoint: txid=0 when meet shutdown.
# 2024-08-17 14:30:13,038 INFO namenode.NameNode: SHUTDOWN_MSG:
# /************************************************************
# SHUTDOWN_MSG: Shutting down NameNode at 5982aab5062b/172.28.0.12
# ************************************************************/
# Starting namenodes on [5982aab5062b]
# 5982aab5062b: Warning: Permanently added '5982aab5062b' (ED25519) to the list of known hosts.
# Starting datanodes
# Starting secondary namenodes [5982aab5062b]
# nohup: ignoring input and appending output to 'nohup.out'
# 1888 ResourceManager
# 2104 Jps
# 1999 NodeManager

# %%
# %%writefile mapper.py
#!/usr/bin/env python

import sys

for line in sys.stdin:
  line = line.strip()
  words = line.split()
  for word in words:
    print('%s\t%s' % (word, 1))
# Out:
# Writing mapper.py

# %%
# %%writefile reducer.py
#!/usr/bin/env python

from operator import itemgetter
import sys

current_word = None
current_count = 0
word = None

for line in sys.stdin:
  line = line.strip()
  word, count = line.split('\t', 1)
  try:
    count = int(count)
  except ValueError:
    continue

  if current_word == word:
    current_count += count
  else:
    if current_word:
      print('%s\t%s' % (current_word, current_count))
    current_count = count
    current_word = word

if current_word == word:
  print('%s\t%s' % (current_word, current_count))
# Out:
# Writing reducer.py

# %%
#Running MapReduce programs
# !$HADOOP_HOME/bin/hadoop jar $HADOOP_HOME/share/hadoop/tools/lib/hadoop-streaming-3.2.3.jar \
  -input /word_count_python/pembukaan_uud1945.txt \
  -output /word_count_python/output \
  -mapper "python /content/mapper.py" \
  -reducer "python /content/reducer.py"

# !$HADOOP_HOME/bin/hdfs dfs -copyToLocal /word_count_python/output/part-00000 /content/pembukaan_uud1945-wordcount.txt
# Out:
# 2024-08-17 14:30:47,832 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2024-08-17 14:30:48,077 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2024-08-17 14:30:48,077 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2024-08-17 14:30:48,097 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2024-08-17 14:30:48,507 INFO mapred.FileInputFormat: Total input files to process : 1
# 2024-08-17 14:30:48,542 INFO mapreduce.JobSubmitter: number of splits:1
# 2024-08-17 14:30:48,719 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1341060779_0001
# 2024-08-17 14:30:48,719 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2024-08-17 14:30:48,926 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2024-08-17 14:30:48,928 INFO mapreduce.Job: Running job: job_local1341060779_0001
# 2024-08-17 14:30:48,935 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2024-08-17 14:30:48,937 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2024-08-17 14:30:48,941 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-08-17 14:30:48,941 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-08-17 14:30:48,982 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2024-08-17 14:30:48,986 INFO mapred.LocalJobRunner: Starting task: attempt_local1341060779_0001_m_000000_0
# 2024-08-17 14:30:49,027 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-08-17 14:30:49,027 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-08-17 14:30:49,058 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2024-08-17 14:30:49,073 INFO mapred.MapTask: Processing split: file:/word_count_python/pembukaan_uud1945.txt:0+1423
# 2024-08-17 14:30:49,088 INFO mapred.MapTask: numReduceTasks: 1
# 2024-08-17 14:30:49,186 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2024-08-17 14:30:49,186 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2024-08-17 14:30:49,186 INFO mapred.MapTask: soft limit at 83886080
# 2024-08-17 14:30:49,186 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2024-08-17 14:30:49,186 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2024-08-17 14:30:49,190 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2024-08-17 14:30:49,198 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper.py]
# 2024-08-17 14:30:49,205 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2024-08-17 14:30:49,205 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2024-08-17 14:30:49,206 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2024-08-17 14:30:49,206 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2024-08-17 14:30:49,207 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2024-08-17 14:30:49,207 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2024-08-17 14:30:49,207 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2024-08-17 14:30:49,208 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2024-08-17 14:30:49,208 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2024-08-17 14:30:49,209 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2024-08-17 14:30:49,209 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2024-08-17 14:30:49,210 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2024-08-17 14:30:49,244 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2024-08-17 14:30:49,313 INFO streaming.PipeMapRed: Records R/W=7/1
# 2024-08-17 14:30:49,330 INFO streaming.PipeMapRed: MRErrorThread done
# 2024-08-17 14:30:49,330 INFO streaming.PipeMapRed: mapRedFinished
# 2024-08-17 14:30:49,337 INFO mapred.LocalJobRunner:
# 2024-08-17 14:30:49,337 INFO mapred.MapTask: Starting flush of map output
# 2024-08-17 14:30:49,337 INFO mapred.MapTask: Spilling map output
# 2024-08-17 14:30:49,337 INFO mapred.MapTask: bufstart = 0; bufend = 1769; bufvoid = 104857600
# 2024-08-17 14:30:49,337 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26213688(104854752); length = 709/6553600
# 2024-08-17 14:30:49,351 INFO mapred.MapTask: Finished spill 0
# 2024-08-17 14:30:49,364 INFO mapred.Task: Task:attempt_local1341060779_0001_m_000000_0 is done. And is in the process of committing
# 2024-08-17 14:30:49,367 INFO mapred.LocalJobRunner: Records R/W=7/1
# 2024-08-17 14:30:49,367 INFO mapred.Task: Task 'attempt_local1341060779_0001_m_000000_0' done.
# 2024-08-17 14:30:49,380 INFO mapred.Task: Final Counters for attempt_local1341060779_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=178133
# 		FILE: Number of bytes written=729317
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=7
# 		Map output records=178
# 		Map output bytes=1769
# 		Map output materialized bytes=2131
# 		Input split bytes=97
# 		Combine input records=0
# 		Spilled Records=178
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=258473984
# 	File Input Format Counters
# 		Bytes Read=1447
# 2024-08-17 14:30:49,381 INFO mapred.LocalJobRunner: Finishing task: attempt_local1341060779_0001_m_000000_0
# 2024-08-17 14:30:49,382 INFO mapred.LocalJobRunner: map task executor complete.
# 2024-08-17 14:30:49,385 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2024-08-17 14:30:49,386 INFO mapred.LocalJobRunner: Starting task: attempt_local1341060779_0001_r_000000_0
# 2024-08-17 14:30:49,395 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-08-17 14:30:49,396 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-08-17 14:30:49,396 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2024-08-17 14:30:49,400 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@27873eef
# 2024-08-17 14:30:49,402 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2024-08-17 14:30:49,423 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2117966208, maxSingleShuffleLimit=529491552, mergeThreshold=1397857792, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2024-08-17 14:30:49,427 INFO reduce.EventFetcher: attempt_local1341060779_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2024-08-17 14:30:49,468 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1341060779_0001_m_000000_0 decomp: 2127 len: 2131 to MEMORY
# 2024-08-17 14:30:49,473 INFO reduce.InMemoryMapOutput: Read 2127 bytes from map-output for attempt_local1341060779_0001_m_000000_0
# 2024-08-17 14:30:49,475 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 2127, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->2127
# 2024-08-17 14:30:49,477 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2024-08-17 14:30:49,478 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2024-08-17 14:30:49,479 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2024-08-17 14:30:49,490 INFO mapred.Merger: Merging 1 sorted segments
# 2024-08-17 14:30:49,490 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 2119 bytes
# 2024-08-17 14:30:49,499 INFO reduce.MergeManagerImpl: Merged 1 segments, 2127 bytes to disk to satisfy reduce memory limit
# 2024-08-17 14:30:49,500 INFO reduce.MergeManagerImpl: Merging 1 files, 2131 bytes from disk
# 2024-08-17 14:30:49,501 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2024-08-17 14:30:49,501 INFO mapred.Merger: Merging 1 sorted segments
# 2024-08-17 14:30:49,504 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 2119 bytes
# 2024-08-17 14:30:49,504 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2024-08-17 14:30:49,516 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/reducer.py]
# 2024-08-17 14:30:49,522 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2024-08-17 14:30:49,524 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2024-08-17 14:30:49,551 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2024-08-17 14:30:49,552 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2024-08-17 14:30:49,554 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2024-08-17 14:30:49,620 INFO streaming.PipeMapRed: Records R/W=178/1
# 2024-08-17 14:30:49,626 INFO streaming.PipeMapRed: MRErrorThread done
# 2024-08-17 14:30:49,627 INFO streaming.PipeMapRed: mapRedFinished
# 2024-08-17 14:30:49,628 INFO mapred.Task: Task:attempt_local1341060779_0001_r_000000_0 is done. And is in the process of committing
# 2024-08-17 14:30:49,629 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2024-08-17 14:30:49,629 INFO mapred.Task: Task attempt_local1341060779_0001_r_000000_0 is allowed to commit now
# 2024-08-17 14:30:49,633 INFO output.FileOutputCommitter: Saved output of task 'attempt_local1341060779_0001_r_000000_0' to file:/word_count_python/output
# 2024-08-17 14:30:49,635 INFO mapred.LocalJobRunner: Records R/W=178/1 > reduce
# 2024-08-17 14:30:49,635 INFO mapred.Task: Task 'attempt_local1341060779_0001_r_000000_0' done.
# 2024-08-17 14:30:49,636 INFO mapred.Task: Final Counters for attempt_local1341060779_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=182427
# 		FILE: Number of bytes written=732747
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=120
# 		Reduce shuffle bytes=2131
# 		Reduce input records=178
# 		Reduce output records=120
# 		Spilled Records=178
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=258473984
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=1299
# 2024-08-17 14:30:49,636 INFO mapred.LocalJobRunner: Finishing task: attempt_local1341060779_0001_r_000000_0
# 2024-08-17 14:30:49,636 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2024-08-17 14:30:49,933 INFO mapreduce.Job: Job job_local1341060779_0001 running in uber mode : false
# 2024-08-17 14:30:49,934 INFO mapreduce.Job:  map 100% reduce 100%
# 2024-08-17 14:30:49,935 INFO mapreduce.Job: Job job_local1341060779_0001 completed successfully
# 2024-08-17 14:30:49,944 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=360560
# 		FILE: Number of bytes written=1462064
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=7
# 		Map output records=178
# 		Map output bytes=1769
# 		Map output materialized bytes=2131
# 		Input split bytes=97
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=120
# 		Reduce shuffle bytes=2131
# 		Reduce input records=178
# 		Reduce output records=120
# 		Spilled Records=356
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=516947968
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=1447
# 	File Output Format Counters
# 		Bytes Written=1299
# 2024-08-17 14:30:49,944 INFO streaming.StreamJob: Output directory: /word_count_python/output
